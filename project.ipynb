# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv (r'/Users/sandyfan/Desktop/project/uber_rides_sample.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# ...

# %%
del df["Unnamed: 0"]

# %%
del df["key"]

# %%
df
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 0               7.5  2015-05-07 19:52:06 UTC        -73.999817
# 1               7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2              12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3               5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4              16.0  2014-08-28 17:47:00 UTC        -73.925023
# ...             ...                      ...               ...
# 199995          3.0  2012-10-28 10:49:00 UTC        -73.987042
# 199996          7.5  2014-03-14 01:09:00 UTC        -73.984722
# 199997         30.9  2009-06-29 00:42:00 UTC        -73.986017
# 199998         14.5  2015-05-20 14:56:25 UTC        -73.997124
# 199999         14.1  2010-05-15 04:08:00 UTC        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0             40.738354         -73.999512         40.723217                1
# ...

# %%
df = df[df["pickup_longitude"] < -73.717047]

# %%
df = df[df["pickup_longitude"] > -74.242330]

# %%
df = df[df["dropoff_longitude"] < -73.717047]

# %%
df = df[df["dropoff_longitude"] > -74.242330]

# %%
df = df[df["pickup_latitude"] < 40.908524]

# %%
df = df[df["pickup_latitude"] > 40.560445]

# %%
df = df[df["dropoff_latitude"] < 40.908524]

# %%
df = df[df["dropoff_latitude"] > 40.560445]

# %%
df
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 0               7.5  2015-05-07 19:52:06 UTC        -73.999817
# 1               7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2              12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3               5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4              16.0  2014-08-28 17:47:00 UTC        -73.925023
# ...             ...                      ...               ...
# 199995          3.0  2012-10-28 10:49:00 UTC        -73.987042
# 199996          7.5  2014-03-14 01:09:00 UTC        -73.984722
# 199997         30.9  2009-06-29 00:42:00 UTC        -73.986017
# 199998         14.5  2015-05-20 14:56:25 UTC        -73.997124
# 199999         14.1  2010-05-15 04:08:00 UTC        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0             40.738354         -73.999512         40.723217                1
# ...

# %%
df.to_csv('uber_data.csv')

# %%
date = df["pickup_datetime"]

# %%
date = pd.to_datetime(date, format = "%Y-%m-%d %H:%M:%S UTC")

# %%
month_name_values = date.groupby([date.dt.year, date.dt.month]).count()

# %%
month_name_values[2015]
# Out:
# pickup_datetime
# 1    2188
# 2    2169
# 3    2324
# 4    2302
# 5    2417
# 6    2114
# Name: pickup_datetime, dtype: int64

# %%
yellow_09_01 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-01.csv')
del yellow_09_01["Rate_Code"]
del yellow_09_01["store_and_forward"]
del yellow_09_01["mta_tax"]
yellow_09_01 = yellow_09_01.sample(month_name_values[2009][1])
yellow_09_01.to_csv('yellow_09_01.csv')

# %%
yellow_09_02 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-02.csv')
del yellow_09_02["Rate_Code"]
del yellow_09_02["store_and_forward"]
del yellow_09_02["mta_tax"]
yellow_09_02 = yellow_09_02.sample(month_name_values[2009][2])
yellow_09_02.to_csv('yellow_09_02.csv')

# %%
yellow_09_03 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-03.csv')
del yellow_09_03["Rate_Code"]
del yellow_09_03["store_and_forward"]
del yellow_09_03["mta_tax"]
yellow_09_03 = yellow_09_03.sample(month_name_values[2009][3])
yellow_09_03.to_csv('yellow_09_03.csv')

# %%
yellow_09_04 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-04.csv')
del yellow_09_04["Rate_Code"]
del yellow_09_04["store_and_forward"]
del yellow_09_04["mta_tax"]
yellow_09_04 = yellow_09_04.sample(month_name_values[2009][4])
yellow_09_04.to_csv('yellow_09_04.csv')

# %%
yellow_09_05 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-05.csv')
del yellow_09_05["Rate_Code"]
del yellow_09_05["store_and_forward"]
del yellow_09_05["mta_tax"]
yellow_09_05 = yellow_09_05.sample(month_name_values[2009][5])
yellow_09_05.to_csv('yellow_09_05.csv')

# %%
yellow_09_06 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-06.csv')
del yellow_09_06["Rate_Code"]
del yellow_09_06["store_and_forward"]
del yellow_09_06["mta_tax"]
yellow_09_06 = yellow_09_06.sample(month_name_values[2009][6])
yellow_09_06.to_csv('yellow_09_06.csv')

# %%
yellow_09_07 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-07.csv')
del yellow_09_07["Rate_Code"]
del yellow_09_07["store_and_forward"]
del yellow_09_07["mta_tax"]
yellow_09_07 = yellow_09_07.sample(month_name_values[2009][7])
yellow_09_07.to_csv('yellow_09_07.csv')

# %%
yellow_09_08 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-08.csv')
del yellow_09_08["Rate_Code"]
del yellow_09_08["store_and_forward"]
del yellow_09_08["mta_tax"]
yellow_09_08 = yellow_09_08.sample(month_name_values[2009][8])
yellow_09_08.to_csv('yellow_09_08.csv')

# %%
yellow_09_09 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-09.csv')
del yellow_09_09["Rate_Code"]
del yellow_09_09["store_and_forward"]
del yellow_09_09["mta_tax"]
yellow_09_09 = yellow_09_09.sample(month_name_values[2009][9])
yellow_09_09.to_csv('yellow_09_09.csv')

# %%
yellow_09_10 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-10.csv')
del yellow_09_10["Rate_Code"]
del yellow_09_10["store_and_forward"]
del yellow_09_10["mta_tax"]
yellow_09_10 = yellow_09_10.sample(month_name_values[2009][10])
yellow_09_10.to_csv('yellow_09_10.csv')

# %%
yellow_09_11 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-11.csv')
del yellow_09_11["Rate_Code"]
del yellow_09_11["store_and_forward"]
del yellow_09_11["mta_tax"]
yellow_09_11 = yellow_09_11.sample(month_name_values[2009][11])
yellow_09_11.to_csv('yellow_09_11.csv')

# %%
yellow_09_12 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2009-12.csv')
del yellow_09_12["Rate_Code"]
del yellow_09_12["store_and_forward"]
del yellow_09_12["mta_tax"]
yellow_09_12 = yellow_09_11.sample(month_name_values[2009][12])
yellow_09_12.to_csv('yellow_09_12.csv')

# %%
yellow_10_01 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2010-01.csv')
del yellow_10_01["Rate_Code"]
del yellow_10_01["store_and_forward"]
del yellow_10_01["mta_tax"]
yellow_10_01 = yellow_09_11.sample(month_name_values[2010][1])
yellow_10_01.to_csv('yellow_10_01.csv')

# %%
yellow_10_02 = pd.read_csv (r'/Users/sandyfan/Desktop/project/yellow_tripdata_2010-02.csv')
del yellow_10_02["Rate_Code"]
del yellow_10_02["store_and_forward"]
del yellow_10_02["mta_tax"]
yellow_10_02 = yellow_09_11.sample(month_name_values[2010][2])
yellow_10_02.to_csv('yellow_10_02.csv')

# %%
import requests
import bs4
import re

# %%
content = requests.get('https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page')

soup = bs4.BeautifulSoup(content.text, 'html.parser')

# %%
[a['href'] for a in soup.find_all('a')][39]
# Out:
# 'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2021-03.csv'

# %%
links = []
for x in [a['href'] for a in soup.find_all('a')]:
    
    string = x
    pattern = re.compile(r"https://s3.amazonaws.com/nyc-tlc/trip\+\bdata/yell.*[\W_]csv")
    match = pattern.findall(string)
    if match != []:
        a = match[0]
        links.append(a)

# %%
yellow_taxi = links[54:]   # get the links of all the years that we need 
yellow_taxi
# Out:
# ['https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-01.csv',
#  'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-02.csv',
#  'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-03.csv',
#  'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-04.csv',
#  'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-05.csv',
#  'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-06.csv',
#  'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-07.csv',
#  'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-08.csv',
#  'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-09.csv',
#  'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-10.csv',
#  'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-11.csv',
#  'https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-12.csv',
# ...

# %%
import pandas as pd

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
yellow_2009_01 = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2015-01.csv')
yellow_2009_01.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...
